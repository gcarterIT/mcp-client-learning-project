# %%
import sys
from importlib.metadata import version

print("Python executable:")
print(sys.executable)

print("\nInstalled packages:")
print(f"mcp: {version('mcp')}")
print(f"streamlit: {version('streamlit')}")
print(f"pydantic: {version('pydantic')}")
# Out:
# Python executable:
# C:\AI_Projects\mcp_client_learning_project\.venv\Scripts\python.exe
#
# Installed packages:
# mcp: 1.28.0
# streamlit: 1.59.2
# pydantic: 2.13.4
